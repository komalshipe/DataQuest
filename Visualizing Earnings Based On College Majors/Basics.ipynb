# %% [markdown]
# # Introduction
# In this section we are going to view the visualization techniques availbale in pandas which we can easily implement in jupyter notebook. This will be somewhat introductory section. So happy learning!!! :)<br>
# Oops! We have to first note the columns and information of those columns
# - **Rank** - Rank by median earnings (the dataset is ordered by this column).
# - **Major_code** - Major code.
# - **Major** - Major description.
# - **Major_category** - Category of major.
# - **Total** - Total number of people with major.
# - **Sample_size** - Sample size (unweighted) of full-time.
# - **Men** - Male graduates.
# - **Women** - Female graduates.
# - **ShareWomen** - Women as share of total.
# - **Employed** - Number employed.
# - **Median** - Median salary of full-time, year-round workers.
# - **Low_wage_jobs** - Number in low-wage service jobs.
# - **Full_time** - Number employed 35 hours or more.
# - **Part_time** - Number employed less than 35 hours.

# %%
# this command helps to render matploblib in jupyter environment
# %matplotlib inline
import matplotlib.pyplot as plt

# %%
# reading the dataset in pandas and checking first row
import pandas as pd
recent_grads = pd.read_csv('recent-grads.csv')
print(recent_grads.iloc[0])
# Out:
# Rank                                        1
# Major_code                               2419
# Major                   PETROLEUM ENGINEERING
# Total                                    2339
# Men                                      2057
# Women                                     282
# Major_category                    Engineering
# ShareWomen                           0.120564
# Sample_size                                36
# Employed                                 1976
# Full_time                                1849
# Part_time                                 270
# Full_time_year_round                     1207
# Unemployed                                 37
# Unemployment_rate                   0.0183805
# Median                                 110000
# P25th                                   95000
# P75th                                  125000
# College_jobs                             1534
# Non_college_jobs                          364
# ...

# %%
# dataframe.head() by default shows 5 rows
recent_grads.head()
# Out:
#    Rank  Major_code                                      Major    Total  \
# 0     1        2419                      PETROLEUM ENGINEERING   2339.0
# 1     2        2416             MINING AND MINERAL ENGINEERING    756.0
# 2     3        2415                  METALLURGICAL ENGINEERING    856.0
# 3     4        2417  NAVAL ARCHITECTURE AND MARINE ENGINEERING   1258.0
# 4     5        2405                       CHEMICAL ENGINEERING  32260.0
#
#        Men    Women Major_category  ShareWomen  Sample_size  Employed  \
# 0   2057.0    282.0    Engineering    0.120564           36      1976
# 1    679.0     77.0    Engineering    0.101852            7       640
# 2    725.0    131.0    Engineering    0.153037            3       648
# 3   1123.0    135.0    Engineering    0.107313           16       758
# 4  21239.0  11021.0    Engineering    0.341631          289     25694
#
#        ...        Part_time  Full_time_year_round  Unemployed  \
# ...

# %%
# dataframe.tail() works same like head command but it takes last rows
recent_grads.tail()
# Out:
#      Rank  Major_code                   Major   Total     Men   Women  \
# 168   169        3609                 ZOOLOGY  8409.0  3050.0  5359.0
# 169   170        5201  EDUCATIONAL PSYCHOLOGY  2854.0   522.0  2332.0
# 170   171        5202     CLINICAL PSYCHOLOGY  2838.0   568.0  2270.0
# 171   172        5203   COUNSELING PSYCHOLOGY  4626.0   931.0  3695.0
# 172   173        3501         LIBRARY SCIENCE  1098.0   134.0   964.0
#
#                Major_category  ShareWomen  Sample_size  Employed  \
# 168    Biology & Life Science    0.637293           47      6259
# 169  Psychology & Social Work    0.817099            7      2125
# 170  Psychology & Social Work    0.799859           13      2101
# 171  Psychology & Social Work    0.798746           21      3777
# 172                 Education    0.877960            2       742
#
#          ...        Part_time  Full_time_year_round  Unemployed  \
# 168      ...             2190                  3602         304
# ...

# %%
# dataframe.describe() function is used for summary statistic of numeric columns
recent_grads.describe()
# Out:
#              Rank   Major_code          Total            Men          Women  \
# count  173.000000   173.000000     172.000000     172.000000     172.000000
# mean    87.000000  3879.815029   39370.081395   16723.406977   22646.674419
# std     50.084928  1687.753140   63483.491009   28122.433474   41057.330740
# min      1.000000  1100.000000     124.000000     119.000000       0.000000
# 25%     44.000000  2403.000000    4549.750000    2177.500000    1778.250000
# 50%     87.000000  3608.000000   15104.000000    5434.000000    8386.500000
# 75%    130.000000  5503.000000   38909.750000   14631.000000   22553.750000
# max    173.000000  6403.000000  393735.000000  173809.000000  307087.000000
#
#        ShareWomen  Sample_size       Employed      Full_time      Part_time  \
# count  172.000000   173.000000     173.000000     173.000000     173.000000
# mean     0.522223   356.080925   31192.763006   26029.306358    8832.398844
# ...

# %%
# checking the size of our dataset
raw_data_count = recent_grads.shape[0]
raw_data_count
# Out:
# 173

# %%
# dropping all rows which contain null values
recent_grads.dropna(axis=0,inplace=True)

# %%
# again checking the size of dataset
cleaned_data_count = recent_grads.shape[0]
print(cleaned_data_count)
# Out:
# 172

# %% [markdown]
# # Visualization
# Now that we have a good dataset of 172 rows without any null values now we can focus on visualization. In following section we are going to visualize the scatter plots of following relations
# - `Sample_size vs Median`
# - `Sample_size vs Unemployment_rate`
# - `Full_time vs Median`
# - `ShareWomen vs Unemployment_rate`
# - `Men vs Median`
# - `Women vs Median`

# %%
recent_grads.plot(x='Sample_size',y='Median',kind='scatter')
plt.show()

# %%
recent_grads.plot(x='Sample_size',y='Unemployment_rate',kind='scatter')
plt.show()

# %% [markdown]
# In above plot we can see that Unemployment_rate is more clustered between sample size 0 to 500.

# %%
recent_grads.plot(x='Full_time',y='Median',kind='scatter')
plt.show()

# %% [markdown]
# In above plot we can see people who are employed for full_time most of them have salary less than 60,000. Only one entry is showing salary over 100000.

# %%
ax = recent_grads.plot(x='ShareWomen',y='Unemployment_rate',kind='scatter')
ax.set_xlim(0,1)
ax.set_ylim(0,1)
plt.show()

# %% [markdown]
# In above plot we can observe unemployment rate and women share is nearly constant.(ShareWomen is defined for majors so irrespective of major unemployment rate is constant for women)

# %%
recent_grads.plot(x='Men',y='Median',kind='scatter')
plt.show()

# %%
recent_grads.plot(x='Women',y='Median',kind='scatter')
plt.show()

# %% [markdown]
# ## Let's check whetere students from popular majors  make more money or not?
# We will take following steps
# 1. First sort the dataset according to Popularity(Total)
# 2. Plot the Major against median salary<br>
# **Note - Since Major is categorical we will show against the index values of new df**

# %%
# first lets make a new df with values sorted by Total column in ascending order
pop_df = recent_grads.sort_values('Total',ascending=True)
pop_df.head()
# Out:
#      Rank  Major_code                                   Major  Total    Men  \
# 73     74        3801                   MILITARY TECHNOLOGIES  124.0  124.0
# 52     53        4005        MATHEMATICS AND COMPUTER SCIENCE  609.0  500.0
# 112   113        1106                            SOIL SCIENCE  685.0  476.0
# 33     34        2411  GEOLOGICAL AND GEOPHYSICAL ENGINEERING  720.0  488.0
# 1       2        2416          MINING AND MINERAL ENGINEERING  756.0  679.0
#
#      Women                       Major_category  ShareWomen  Sample_size  \
# 73     0.0  Industrial Arts & Consumer Services    0.000000            4
# 52   109.0              Computers & Mathematics    0.178982            7
# 112  209.0      Agriculture & Natural Resources    0.305109            4
# 33   232.0                          Engineering    0.322222            5
# 1     77.0                          Engineering    0.101852            7
#
# ...

# %% [markdown]
# Ohhh! The index column has values which are not order so it will be not a good to put it like that way so lets fix it.

# %%
pop_df = pop_df.reset_index(drop=True)
pop_df[['Major','Total']].head()
# Out:
#                                     Major  Total
# 0                   MILITARY TECHNOLOGIES  124.0
# 1        MATHEMATICS AND COMPUTER SCIENCE  609.0
# 2                            SOIL SCIENCE  685.0
# 3  GEOLOGICAL AND GEOPHYSICAL ENGINEERING  720.0
# 4          MINING AND MINERAL ENGINEERING  756.0

# %%
pop_df[['Major','Total']].tail()
# Out:
#                                       Major     Total
# 167                          COMMUNICATIONS  213996.0
# 168                        GENERAL BUSINESS  234590.0
# 169                                 BIOLOGY  280709.0
# 170  BUSINESS MANAGEMENT AND ADMINISTRATION  329927.0
# 171                              PSYCHOLOGY  393735.0

# %% [markdown]
# Now this looks cool. Let's plot histogram and line graph.

# %%
ax = pop_df.reset_index().plot(x='index',y='Median',kind='bar')
#ax.set_xlabel([i for i in range(pop_df.shape[0])])
ax.set_xticks([0,pop_df.shape[0]])
plt.show()

# %%
pop_df.reset_index().plot(x='index',y='Median',kind='line')
plt.show()

# %% [markdown]
# So by observing graph we can roughly esitmate that the less popular majors have more salary compared to majors which have more students.

# %% [markdown]
# ## Let's check whether females make more money where the share of women was more in those majors are highly salaried or not
# 1. First sort the df with respect to sharewomen
# 2. Plot the salary median and sharewomen in line graph

# %%
# we will do all steps in one line only as we have done it earlier
women_df = recent_grads.sort_values('ShareWomen').reset_index(drop=True)
women_df[['Median','ShareWomen']].head()
# Out:
#    Median  ShareWomen
# 0   40000    0.000000
# 1   40000    0.077453
# 2   50000    0.090713
# 3   75000    0.101852
# 4   70000    0.107313

# %%
women_df.plot(x='ShareWomen',y='Median')
plt.show()

# %% [markdown]
# The graph is indicating that the majors which has women share less are highly paid and as women salary increases the salary decreases. **This indicates that the majors in which women share is high are less paid.**

# %% [markdown]
# ### Now we have encountered some questions let's try to focus on histograms for visualization tasks
# In this section we will visualize all numeric columns in histograms.<br>
# Histogram shows general trends lying inside data, like which value is most common

# %%
recent_grads['Sample_size'].hist(bins=10)
plt.show()

# %%
recent_grads['Median'].hist(bins=10)
plt.show()

# %% [markdown]
# In above histogram we can see that salary above 100000 is very uncommon where the salary around 30000-40000 is common.

# %%
recent_grads['Employed'].hist(bins=10)
plt.show()

# %%
recent_grads['Full_time'].hist(bins=10,range=(0,27000))
plt.show()

# %%
recent_grads['ShareWomen'].hist(bins=10,range=(0,1))
plt.show()

# %%
recent_grads['Unemployment_rate'].hist(bins=9,range=(0,0.18))
plt.show()

# %%
recent_grads['Men'].hist(bins=9,range=(0,180000))
plt.show()

# %%
recent_grads['Women'].hist(bins=7,range=(0,35000))
plt.show()

# %%
from pandas.tools.plotting import scatter_matrix
scatter_matrix(recent_grads[['Sample_size','Median']])
scatter_matrix(recent_grads[['Sample_size','Median','Unemployment_rate']])
plt.show()

# %%
recent_grads.sort_values('Median',ascending=False,inplace='True')
recent_grads.head()
# Out:
#    Rank  Major_code                                      Major    Total  \
# 0     1        2419                      PETROLEUM ENGINEERING   2339.0
# 1     2        2416             MINING AND MINERAL ENGINEERING    756.0
# 2     3        2415                  METALLURGICAL ENGINEERING    856.0
# 3     4        2417  NAVAL ARCHITECTURE AND MARINE ENGINEERING   1258.0
# 4     5        2405                       CHEMICAL ENGINEERING  32260.0
#
#        Men    Women Major_category  ShareWomen  Sample_size  Employed  \
# 0   2057.0    282.0    Engineering    0.120564           36      1976
# 1    679.0     77.0    Engineering    0.101852            7       640
# 2    725.0    131.0    Engineering    0.153037            3       648
# 3   1123.0    135.0    Engineering    0.107313           16       758
# 4  21239.0  11021.0    Engineering    0.341631          289     25694
#
#        ...        Part_time  Full_time_year_round  Unemployed  \
# ...

# %% [markdown]
# ### Comparison of jobs for male and female
# Now we will compare jobs for female first then male candidates

# %%
recent_grads[:10].plot.bar(x='Major',y='ShareWomen')
recent_grads.tail(10).plot.bar(x='Major',y='ShareWomen')
plt.show()

# %% [markdown]
# Here we can see the majors in which women share is high are low paying.

# %%
recent_grads[:10].plot.bar(x='Major',y='Unemployment_rate')
recent_grads[recent_grads.shape[0]-10:].plot.bar(x='Major',y='Unemployment_rate')
plt.show()

# %% [markdown]
# We can't see any major difference in Unemployment_rate. So let's use some other graphs to check if unemployment_rate is dependent on something or not or it's just same everywhere.

# %%
# here we are using reset_index so that we can use index as one value 
# because we can't use major name in line plot so we are using ranking of
# major
ax = recent_grads.reset_index().plot(y='Unemployment_rate',x='index')
ax.set_xlabel('Majors ranking (paying)')
plt.show()

# %% [markdown]
# So there is no clear indication of unemployment_rate depending upon major ranking based upon payscale.<br>
# Lets' draw a plot based upon popularity of majors

# %%
ax = pop_df.reset_index().plot(x='index',y='Unemployment_rate')
ax.set_xlabel('Majors ranking (total students)')

# %% [markdown]
# Here note one thing that the majors ranking is going high from left to right.

# %%
pop_df.head()
# Out:
#    Rank  Major_code                                   Major  Total    Men  \
# 0    74        3801                   MILITARY TECHNOLOGIES  124.0  124.0
# 1    53        4005        MATHEMATICS AND COMPUTER SCIENCE  609.0  500.0
# 2   113        1106                            SOIL SCIENCE  685.0  476.0
# 3    34        2411  GEOLOGICAL AND GEOPHYSICAL ENGINEERING  720.0  488.0
# 4     2        2416          MINING AND MINERAL ENGINEERING  756.0  679.0
#
#    Women                       Major_category  ShareWomen  Sample_size  \
# 0    0.0  Industrial Arts & Consumer Services    0.000000            4
# 1  109.0              Computers & Mathematics    0.178982            7
# 2  209.0      Agriculture & Natural Resources    0.305109            4
# 3  232.0                          Engineering    0.322222            5
# 4   77.0                          Engineering    0.101852            7
#
#    Employed      ...        Part_time  Full_time_year_round  Unemployed  \
# ...

# %%
recent_grads.head()[['Men','Women']].plot.bar()
plt.show()

# %%
recent_grads.tail()[['Men','Women']].plot.bar()
plt.show()

# %% [markdown]
# We can see a clear difference between men and women strength depending upon their paying majors.

# %%
#fig = plt.figure(figsize=(12,5))
#ax = fig.add_subplot()
ax=recent_grads.boxplot('Median',by='Major_category',rot=90,figsize=(12,12))
ax.set_ylim(20000,80000)
plt.show()

# %%
ax=recent_grads.plot.hexbin(x='Full_time',y='Median')
ax.set_ylim
plt.show()
